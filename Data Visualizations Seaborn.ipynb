# %%
import seaborn as sns
import pandas as pd
heart = pd.read_csv('C:/Users/Asus/Desktop/BOOTCAMP/Data/heart.csv')
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
#barplot
sns.barplot(x = 'thal', y = 'sex', data = heart)
# Out:
# <AxesSubplot:xlabel='thal', ylabel='sex'>

# %%
#box plot
sns.boxplot(x = 'sex', y = 'chol', data = heart)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='chol'>

# %%
#violin plot
sns.violinplot(x = 'sex', y = 'chol', data = heart)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='chol'>

# %%
#strip plot
sns.stripplot(x = 'sex', y = 'chol', data = heart)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='chol'>

# %%
#count plot
sns.countplot(x = 'sex', data = heart)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data_cdi = pd.read_csv('C:/Users/Asus/Desktop/BOOTCAMP/Data/Cause-of-Death-Indonesia.csv')
data_cdi
# Out:
#                         Cause                           Type  Year  \
# 0             Abrasi Air Laut                   Bencana Alam  2012
# 1                        AIDS  Bencana Non Alam dan Penyakit  2000
# 2                        AIDS  Bencana Non Alam dan Penyakit  2001
# 3                        AIDS  Bencana Non Alam dan Penyakit  2002
# 4                        AIDS  Bencana Non Alam dan Penyakit  2003
# ..                        ...                            ...   ...
# 675  Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit  2016
# 676  Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit  2017
# 677  Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit  2019
# 678  Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit  2020
# 679  Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit  2021
#
#      Data Redundancy  Total Deaths                                 Source  \
# 0                  1             0  Profil Kesehatan Indonesia Tahun 2012
# ...

# %%
#kategorikan jumlah total kematian(total deaths) berdasarkan tahun(year)
group = data_cdi.groupby('Year')['Total Deaths'].sum()
group
# Out:
# Year
# 2000       339
# 2001       324
# 2002       435
# 2003       633
# 2004    220744
# 2005    123036
# 2006    127065
# 2007     89275
# 2008    106298
# 2009     33124
# 2010     39261
# 2011      2173
# 2012      1834
# 2013      1145
# 2014      1199
# 2015      2356
# 2016      2624
# 2017      1044
# 2018      4976
# 2019     14697
# 2020     38063
# 2021    139106
# 2022     12876
# Name: Total Deaths, dtype: int64

# %%
#visualisasi barplot & menentukan tahun yg memiliki total kematian tertinggi
plt.figure(figsize=[15,5])
#15 itu panjangnya, 5 itu lebar
sns.barplot(x = 'Year', y = 'Total Deaths', data = group.reset_index(), ci=0)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total Deaths'>

# %%
#2. conditional selection untuk nyari data type = bencana sosial
bencana_sosial = data_cdi[data_cdi['Type'] == 'Bencana Sosial']
bencana_sosial
# Out:
#                                     Cause            Type  Year  \
# 16                Aksi Teror dan Sabotase  Bencana Sosial  2015
# 17                Aksi Teror dan Sabotase  Bencana Sosial  2016
# 18                Aksi Teror dan Sabotase  Bencana Sosial  2017
# 19                Aksi Teror dan Sabotase  Bencana Sosial  2018
# 20                Aksi Teror dan Sabotase  Bencana Sosial  2019
# 21                Aksi Teror dan Sabotase  Bencana Sosial  2020
# 22                Aksi Teror dan Sabotase  Bencana Sosial  2021
# 124                     Bencana kelaparan  Bencana Sosial  2006
# 451                               Konflik  Bencana Sosial  2009
# 452                               Konflik  Bencana Sosial  2010
# 453                               Konflik  Bencana Sosial  2011
# 454                        Konflik Sosial  Bencana Sosial  2008
# 455                        Konflik Sosial  Bencana Sosial  2012
# 456  Konflik Sosial atau Kerusuhan Sosial  Bencana Sosial  2015
# ...

# %%
group2 = bencana_sosial.groupby('Cause')['Total Deaths'].sum()
group2
# Out:
# Cause
# Aksi Teror dan Sabotase                 42
# Bencana kelaparan                        1
# Konflik                                 83
# Konflik Sosial                          66
# Konflik Sosial atau Kerusuhan Sosial    69
# Name: Total Deaths, dtype: int64

# %%
#Visualisasi
plt.figure(figsize=[15,5])
#15 itu panjangnya, 5 itu lebar
sns.barplot(x = 'Total Deaths', y = 'Cause', data = group2.reset_index(), ci=0)
# Out:
# <AxesSubplot:xlabel='Total Deaths', ylabel='Cause'>
