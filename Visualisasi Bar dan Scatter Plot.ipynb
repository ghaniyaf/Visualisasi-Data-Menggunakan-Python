# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Cleaning Data

# %%
superstore.dropna()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9988  Standard Class  Corporate  United States           Athens     Georgia
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
#
# ...

# %% [markdown]
# Data Superstore
# 1. Menghitung Jumlah Data pada Ship Mode

# %%
group = superstore.groupby('Ship Mode').count()
group
# Out:
#                 Segment  Country  City  State  Postal Code  Region  Category  \
# Ship Mode
# First Class        1538     1538  1538   1538         1538    1538      1538
# Same Day            543      543   543    543          543     543       543
# Second Class       1944     1944  1944   1944         1944    1944      1944
# Standard Class     5968     5968  5968   5968         5968    5968      5968
#
#                 Sub-Category  Sales  Quantity  Discount  Profit
# Ship Mode
# First Class             1538   1538      1538      1538    1538
# Same Day                 543    543       543       543     543
# Second Class            1944   1944      1944      1944    1944
# Standard Class          5968   5968      5968      5968    5968

# %%
group = superstore.groupby('Ship Mode')['Quantity'].count()
group
# Out:
# Ship Mode
# First Class       1538
# Same Day           543
# Second Class      1944
# Standard Class    5968
# Name: Quantity, dtype: int64

# %% [markdown]
# Visualisasi Data Bar Plot Menggunakan Seaborn

# %%
sns.barplot(x = 'Ship Mode', y = 'Quantity', data = group.reset_index(), ci =0)
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Quantity'>

# %% [markdown]
# Visualisasi Data Bar Plot Menggunakan Matplotlib

# %%
group.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Ship Mode'>

# %% [markdown]
# Menghitung Jumlah Penjualan Setiap Region

# %%
group3 = superstore.groupby('Region') ['Sales'].sum()
group3
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725214.6645
# Name: Sales, dtype: float64

# %% [markdown]
# Visualisasi Data Bar Plot untuk Menampilkan Jumlah Penjualan Setiap Region Menggunakan Seaborn

# %%
sns.barplot(x = 'Region', y = 'Sales', data = group3.reset_index(), ci =0)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %% [markdown]
# Menghitung Jumlah Keuntungan Setiap Kategori

# %%
group4 = superstore.groupby('Category') ['Profit'].sum()
group4
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122417.8528
# Technology         145454.9481
# Name: Profit, dtype: float64

# %% [markdown]
# Visualisasi Data Bar Plot untuk Menampilkan Keuntungan Setiap Kategori Menggunakan Seaborn

# %%
sns.barplot(x = 'Category', y = 'Profit', data = group4.reset_index(), ci =0)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Profit'>

# %% [markdown]
# Visualisasi Scatter Plot untuk Menampilkan Hubungan antara Diskon dan Keuntungan

# %% [markdown]
# Dapat disimpulkan, semakin banyaknya diskon, semakin kecil keuntungan yang didapatkan

# %%
# alpha = transparan
# s untuk ukuran lingkaran
# label untuk menambahkan legend

plt.figure(figsize=(15,5))

plt.scatter(superstore['Discount'], superstore['Profit'], alpha = 0.5, s = 50, label = 'Profit')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.title('Discount and Profit')
plt.legend()
